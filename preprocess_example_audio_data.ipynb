# %%
from my_func_pkg import key_index2

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import librosa

# %%
file_name = '/content/drive/MyDrive/output_data/Ebi - Adat [320]/vocals.wav'  # نام فایل آپلود شده
audio_data, sample_rate = librosa.load(file_name, sr=None)

# %%
len(audio_data)
# Out:
# 13535760

# %%
len(audio_data)/sample_rate
# Out:
# 306.93333333333334

# %%
(len(audio_data)/sample_rate)/60
# Out:
# 5.115555555555556

# %%
key_data=key_index2(audio_data,int(len(audio_data)/2),100)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
#   9%|▉         | 9/100 [00:32<05:16,  3.48s/it]/usr/local/lib/python3.10/dist-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
#  15%|█▌        | 15/100 [00:53<04:59,  3.52s/it]/usr/local/lib/python3.10/dist-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
#  16%|█▌        | 16/100 [00:56<04:43,  3.38s/it]/usr/local/lib/python3.10/dist-packages/scipy/interpolate/_interpolate.py:712: RuntimeWarning: invalid value encountered in divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# ...

# %%
plt.plot(audio_data[key_data])
plt.show()

# %%
new_audio_data=audio_data[key_data]

# %%
import soundfile as sf

# ذخیره آرایه عددی به عنوان فایل صوتی
output_filename = '/content/output_data/'+'output_audio.wav'
sf.write(output_filename, new_audio_data, sample_rate)
