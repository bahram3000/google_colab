# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
with open('/content/drive/MyDrive/output_data/all_data.pickle', 'rb') as f:
    loaded_data = pickle.load(f)

# %%
plt.plot(loaded_data[1])

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !git config --global user.email "bahramlpmt@gmail.com"
# !git config --global user.name "bahram3000"

# %%
# !git clone https://github.com/bahram3000/google_colab.git
# Out:
# Cloning into 'google_colab'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !cp /content/drive/MyDrive/output_data/all_data.pickle /content/google_colab/

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/spleet_vocal.ipynb" /content/google_colab/

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/extract_data_from_vocals.ipynb" /content/google_colab/

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/preprocess_example_audio_data.ipynb" /content/google_colab/
