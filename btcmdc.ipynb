# %% [markdown]
# <a href="https://colab.research.google.com/github/bahram3000/google_colab/blob/main/btcmdc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from my_func_pkg import most_frequency_cenarios,blind_boundary_exp_smooth_curve
import yfinance as yf
import matplotlib.pyplot as plt

# %%
btc_dt=yf.download(tickers='BTC-USD',interval='1m')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
plt.plot(btc_dt['Close'].values)

# %%
future_len=30

# %%
btc_close=btc_dt['Close'].values[:,0]

# %%
mfcbtc=most_frequency_cenarios(btc_close,nbins=10,ngreater=0.9,ncenarios=500,lcenarios=future_len)
# Out:
# 100%|██████████| 500/500 [04:00<00:00,  2.08it/s]

# %%
mfcbtc
# Out:
# array([83409.83784658, 83704.52024707, 83999.20264756, 84293.88504806])
