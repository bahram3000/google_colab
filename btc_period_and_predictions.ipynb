# %% [markdown]
# <a href="https://colab.research.google.com/github/bahram3000/google_colab/blob/main/btc_period_and_predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from my_func_pkg import find_best_period_for_dependency,blind_boundary_exp_smooth_curve,most_frequency_cenarios

# %%
import yfinance as yf

# %%
btc=yf.download('BTC-USD',interval='1D')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
fbpdun=find_best_period_for_dependency(btc.Close.values,overlay=False)
# Out:
# 100%|██████████| 1869/1869 [05:26<00:00,  5.72it/s]
# Enter your number of points :100
# Enter your number of try fit :500
# 100%|██████████| 500/500 [00:00<00:00, 1338.70it/s]

# %%
from my_func_pkg import intersect,fix_num_key_index

# %%
import matplotlib.pyplot as plt

# %%
fnki=fix_num_key_index(fbpdun[0],point_num=100,max_iter=500)
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 1378.38it/s]

# %%
plt.plot(fbpdun[0])
plt.plot(fnki,fbpdun[0][fnki])
plt.show()

# %%
import pandas as pd

# %%
pd.DataFrame(fbpdun[0]).to_csv('fbpdun.csv')

# %%
fbpdov=find_best_period_for_dependency(btc.Close.values,overlay=True)
# Out:
# 100%|██████████| 3741/3741 [36:34<00:00,  1.70it/s]

# %%
len(fbpdov[0])
# Out:
# 14013786

# %%
plt.plot(fbpdov[0])
#plt.plot(fbpdov[1])
plt.show()
