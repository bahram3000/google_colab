# %%
import os
import numpy as np

# %%
#!pip install spleeter

# %%
from spleeter.separator import Separator

# %%
separator = Separator('spleeter:2stems')

# %%
#os.listdir('/content/input_data')

# %%
for i in os.listdir('/content/input_data'):
  inp_path='/content/input_data/'+i
  out_path='/content/output_data'
  separator.separate_to_file(inp_path, out_path)

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp -r /content/output_data /content/drive/MyDrive/
# Out:
# Mounted at /content/drive

# %%
#!pip install librosa matplotlib

# %%
import librosa
import matplotlib.pyplot as plt

# %%
file_name = '/content/output_data/Ebi - Adat [320]/vocals.wav'  # نام فایل آپلود شده
audio_data, sample_rate = librosa.load(file_name, sr=None)

# %%
plt.figure(figsize=(10, 4))
plt.plot(audio_data)
plt.title('Waveform of the audio file')
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.show()

# %%
audio_data[audio_data>0]
# Out:
# array([1.5258789e-05, 1.5258789e-05, 1.5258789e-05, ..., 1.5258789e-05,
#        1.5258789e-05, 1.5258789e-05], dtype=float32)

# %%
plt.figure(figsize=(10, 4))
plt.plot(audio_data[np.abs(audio_data)>0.0004])
plt.title('Waveform of the audio file')
plt.xlabel('Time (samples)')
plt.ylabel('Amplitude')
plt.show()

# %%
#!pip install soundfile

# %%
new_audio_data=audio_data[np.abs(audio_data)>0.0004]

# %%
import soundfile as sf

# ذخیره آرایه عددی به عنوان فایل صوتی
output_filename = '/content/output_data/'+'output_audio.wav'
sf.write(output_filename, new_audio_data, sample_rate)
